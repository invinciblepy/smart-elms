# %% [markdown]
# # Smart ELMS — EDA and model training
#
# Malik Rashid Mehmood · AI prediction module
#
# This notebook reproduces the synthetic dataset, exploratory analysis and the Decision Tree vs Logistic Regression comparison. The same logic lives in `ai/generate_dataset.py` and `ai/train_models.py` so the Flask app and this notebook cannot drift apart.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks":
    ROOT = ROOT.parents[1]
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from ai.generate_dataset import generate_dataset
from ai.train_models import train

df = generate_dataset(n=520)
df.head()

# %%
print(df.describe())
print("class balance:\n", df["at_risk"].value_counts(normalize=True))

# %%
report = train(df)
report
